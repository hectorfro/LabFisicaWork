# %% [markdown]
# ## Notebook del capítulo 4

# %%
# 21/5/24
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
y = 5*10**(1/3*x)
plt.plot(x, y, 'o')
plt.show()

# %%
plt.plot(x, y, '-o')
plt.yscale("log")
plt.show()

# %%
x = np.arange(20)
y = 8*x**(3)
plt.plot(x, y, '*')
plt.show()

# %%
plt.plot(x, y, '-*')
plt.xscale("log")
plt.yscale("log")
plt.show()
